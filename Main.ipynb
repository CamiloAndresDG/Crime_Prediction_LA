# %% [markdown]
# # Import libreries

# %%
# Libreries for data manipulation
import pandas as pd

# ========================================================
# Import of libraries necessary for data manipulation and exploration.
# ========================================================
import pandas as pd
from datetime import datetime
import numpy as np
import warnings
from sklearn.metrics import mean_squared_error
import joblib

# ========================================================
# Import of modules where the logic is located behind the vast majority of lines.
# ========================================================
import Descriptive_Analysis as descriptive

# %%
# Read the CSV file
crime_data = pd.read_csv("D:\Datasets\Crime_Data_from_2020_to_Present.csv", sep=',', encoding='utf8')

# %% [markdown]
# # Descriptive analysis

# %%
# Dataframe's information
descriptive.df_info(crime_data)
# Out:
# ...
# Shape
# (963006, 28)
# --------------------------------
# Nulls
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           139117
# Vict Age               0
# Vict Sex          132501
# Vict Descent      132511
# Premis Cd             14
# Premis Desc          575
# Weapon Used Cd    637661
# Weapon Desc       637661
# Status                 1
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          894402
# Crm Cd 3          960705
# Crm Cd 4          962942
# LOCATION               0
# Cross Street      813230
# LAT                    0
# LON                    0
# dtype: int64
# --------------------------------
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963006 entries, 0 to 963005
# Data columns (total 28 columns):
# ...
